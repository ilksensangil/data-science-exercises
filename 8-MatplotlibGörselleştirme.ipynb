# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
numpyDizisi1=np.linspace(1,10,20)

# %%
numpyDizisi1
# Out:
# array([ 1.        ,  1.47368421,  1.94736842,  2.42105263,  2.89473684,
#         3.36842105,  3.84210526,  4.31578947,  4.78947368,  5.26315789,
#         5.73684211,  6.21052632,  6.68421053,  7.15789474,  7.63157895,
#         8.10526316,  8.57894737,  9.05263158,  9.52631579, 10.        ])

# %%
numpyDizisi2=numpyDizisi1**2

# %%
(benimFigur,benimEksen)=pyt.subplots()
benimEksen.plot(numpyDizisi1,numpyDizisi2, color ="#3A95A8",alpha=0.3) # renk kodunu yazdık alpha = saydamlık kattı
benimEksen.plot(numpyDizisi2,numpyDizisi1, color ="#C96F23")

# %%
(yeniFigur,yeniEksen)=pyt.subplots()
yeniEksen.plot(numpyDizisi1,numpyDizisi1+2, color ="blue",linewidth=3.0) # mavi çizgimizi kalınlaştıracak
yeniEksen.plot(numpyDizisi1,numpyDizisi1+3, color ="yellow")
yeniEksen.plot(numpyDizisi1,numpyDizisi1+4, color ="red", linestyle="--") # kırmızı çizgiyi çizikli olarak gösterdi.
yeniEksen.plot(numpyDizisi1,numpyDizisi1+5, color ="black", linestyle="--" , marker="+")# siyah çizginin üstüne artıları ekledik

# %% [markdown]
# ## scatter

# %%
plt.scatter(numpyDizisi1,numpyDizisi2)  # grafiği dağıtık şekilde çiziyor

# %% [markdown]
# ## histogram

# %%
yeniDizi=np.random.randint(0,100,50)

# %%
yeniDizi
# Out:
# array([37, 28, 55, 64, 29, 75,  8, 35,  2, 48, 29,  0, 25, 36,  4,  6, 91,
#         3, 44, 91, 10, 54, 88, 81, 10, 98, 63, 57,  4, 94, 73, 19, 42, 75,
#        74, 34, 39, 58, 47, 91,  5, 82, 84, 75, 92, 18, 14, 11, 84, 43])

# %%
plt.hist(yeniDizi)
# Out:
# (array([8., 6., 4., 5., 5., 4., 2., 5., 5., 6.]),
#  array([ 0. ,  9.8, 19.6, 29.4, 39.2, 49. , 58.8, 68.6, 78.4, 88.2, 98. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## boxplot

# %%
plt.boxplot(yeniDizi)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d5f2ab2820>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d5f2ab2f10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d5f2ab24c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d5f2a95610>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d5f2a95970>],
#  'means': []}
